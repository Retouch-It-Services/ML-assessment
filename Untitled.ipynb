# %%
# ==============================================================
# STEP 1: IMPORT LIBRARIES & LOAD DATA
# ==============================================================

import os
import zipfile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import (
    brier_score_loss, 
    classification_report, 
    confusion_matrix, 
    roc_auc_score
)
from sklearn.calibration import CalibratedClassifierCV, calibration_curve

# Models
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC

# Ignore warnings for clarity
import warnings
warnings.filterwarnings('ignore')

# ==============================================================
# STEP 1.1: PATH SETUP (UPDATE BELOW)
# ==============================================================

DATA_ZIP_PATH = r"C:\Users\YourName\Downloads\diabetes+130-us+hospitals+for+years+1999-2008 (1).zip"
EXTRACT_DIR = r"C:\Users\YourName\Downloads\diabetes_readmission"

# Extract ZIP if not already extracted
os.makedirs(EXTRACT_DIR, exist_ok=True)
with zipfile.ZipFile(DATA_ZIP_PATH, 'r') as z:
    z.extractall(EXTRACT_DIR)

# Find CSV automatically
CSV_PATH = None
for root, dirs, files in os.walk(EXTRACT_DIR):
    for f in files:
        if f.lower().endswith('.csv'):
            CSV_PATH = os.path.join(root, f)
            break
    if CSV_PATH:
        break

if CSV_PATH is None:
    raise FileNotFoundError('CSV file not found in the extracted archive.')

print(f"✅ Using dataset: {CSV_PATH}")

# Load data
df = pd.read_csv(CSV_PATH)
print("✅ Data loaded successfully!")
print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[20], line 40
#      37 EXTRACT_DIR = r"C:\Users\YourName\Downloads\diabetes_readmission"
#      39 # Extract ZIP if not already extracted
# ---> 40 os.makedirs(EXTRACT_DIR, exist_ok=True)
#      41 with zipfile.ZipFile(DATA_ZIP_PATH, 'r') as z:
#      42     z.extractall(EXTRACT_DIR)
#
# File C:\ProgramData\anaconda3\Lib\os.py:218, in makedirs(name, mode, exist_ok)
#     216 if head and tail and not path.exists(head):
#     217     try:
# --> 218         makedirs(head, exist_ok=exist_ok)
#     219     except FileExistsError:
#     220         # Defeats race condition when another thread created the path
#     221         pass
#
# File C:\ProgramData\anaconda3\Lib\os.py:218, in makedirs(name, mode, exist_ok)
#     216 if head and tail and not path.exists(head):
#     217     try:
# ...

# %%
# --------------------------- 2) Load & unzip dataset ---------------------------
import os
import zipfile

DATA_ZIP_PATH = '/mnt/data/diabetes+130-us+hospitals+for+years+1999-2008 (1).zip'
EXTRACT_DIR = '/mnt/data/diabetes_readmission'

os.makedirs(EXTRACT_DIR, exist_ok=True)

# ✅ FIXED INDENTATION
with zipfile.ZipFile(DATA_ZIP_PATH, 'r') as z:
    z.extractall(EXTRACT_DIR)

# The typical filename in this UCI bundle is 'diabetic_data.csv'. Adjust if different.
CSV_PATH = None
for root, dirs, files in os.walk(EXTRACT_DIR):
    for f in files:
        if f.lower().endswith('.csv'):
            CSV_PATH = os.path.join(root, f)
            break
    if CSV_PATH:
        break

if CSV_PATH is None:
    raise FileNotFoundError('CSV file not found in the extracted archive. Check DATA_ZIP_PATH and contents.')

print('Using CSV:', CSV_PATH)

# Read the dataset
df = pd.read_csv(CSV_PATH)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 11
#       8 os.makedirs(EXTRACT_DIR, exist_ok=True)
#      10 # ✅ FIXED INDENTATION
# ---> 11 with zipfile.ZipFile(DATA_ZIP_PATH, 'r') as z:
#      12     z.extractall(EXTRACT_DIR)
#      14 # The typical filename in this UCI bundle is 'diabetic_data.csv'. Adjust if different.
#
# File C:\ProgramData\anaconda3\Lib\zipfile\__init__.py:1367, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1365 while True:
#    1366     try:
# -> 1367         self.fp = io.open(file, filemode)
#    1368     except OSError:
#    1369         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/data/diabetes+130-us+hospitals+for+years+1999-2008 (1).zip'
